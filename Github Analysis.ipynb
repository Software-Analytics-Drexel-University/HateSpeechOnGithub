# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/Users/dymonmoore/Downloads/replication_package_msr_2022/datasets/sentence_level.csv.csv', header=0)
df
# Out:
#         id  issue_id  comment_id  \
# 0        1     22859       22859
# 1        2     22859   374154097
# 2        3     22859   374154097
# 3        4     22859   374154851
# 4        5     22859   374155138
# ...    ...       ...         ...
# 1359  1360      4518   500270587
# 1360  1361      4518   752301544
# 1361  1362      4518   752365666
# 1362  1363      4518   822085425
# 1363  1364      4518   822104201
#
#                                               quotation  \
# 0         This is the worst framework i have ever seen.
# 1     I have real project with Angular, and the only...
# 2     I have real project with Angular, and the only...
# 3     when you deal with real big scale project - th...
# 4     Your issue doesn't contain a single bit of use...
# ...                                                 ...
# 1359  Replace the template text and remove irrelevan...
# 1360  Seems more like Bram enjoys taking all the cre...
# 1361  I think it is more important that the main dev...
# 1362  No, I don't understand.\n\nAny software develo...
# 1363  To think that\na new idea is better than an ol...
#
#                         quotation_code comment_code issue_code  \
# 0                      Dissatisfaction        civil    uncivil
# 1                      Dissatisfaction        civil    uncivil
# 2                              Sadness        civil    uncivil
# 3                              Sadness        civil    uncivil
# 4                         Name calling      uncivil    uncivil
# ...                                ...          ...        ...
# 1359                        Commanding        civil    uncivil
# 1360                           Mocking      uncivil    uncivil
# 1361                   Dissatisfaction        civil    uncivil
# 1362  Annoyance and Bitter frustration      uncivil    uncivil
# 1363  Annoyance and Bitter frustration      uncivil    uncivil
#
#      sentiment_quotation
# 0               negative
# 1               negative
# 2               negative
# 3               negative
# 4                uncivil
# ...                  ...
# 1359            negative
# 1360             uncivil
# 1361            negative
# 1362             uncivil
# 1363             uncivil
#
# [1364 rows x 8 columns]

# %%
df = pd.read_csv('/Users/dymonmoore/Downloads/replication_package_msr_2022/datasets/sentence_level.csv.csv', header=0,
        usecols=["comment_id", "quotation", "quotation_code", 'comment_code', 'sentiment_quotation'])
df
# Out:
#       comment_id                                          quotation  \
# 0          22859      This is the worst framework i have ever seen.
# 1      374154097  I have real project with Angular, and the only...
# 2      374154097  I have real project with Angular, and the only...
# 3      374154851  when you deal with real big scale project - th...
# 4      374155138  Your issue doesn't contain a single bit of use...
# ...          ...                                                ...
# 1359   500270587  Replace the template text and remove irrelevan...
# 1360   752301544  Seems more like Bram enjoys taking all the cre...
# 1361   752365666  I think it is more important that the main dev...
# 1362   822085425  No, I don't understand.\n\nAny software develo...
# 1363   822104201  To think that\na new idea is better than an ol...
#
#                         quotation_code comment_code sentiment_quotation
# 0                      Dissatisfaction        civil            negative
# 1                      Dissatisfaction        civil            negative
# 2                              Sadness        civil            negative
# 3                              Sadness        civil            negative
# 4                         Name calling      uncivil             uncivil
# ...                                ...          ...                 ...
# 1359                        Commanding        civil            negative
# 1360                           Mocking      uncivil             uncivil
# 1361                   Dissatisfaction        civil            negative
# 1362  Annoyance and Bitter frustration      uncivil             uncivil
# 1363  Annoyance and Bitter frustration      uncivil             uncivil
#
# [1364 rows x 5 columns]

# %%
df.loc[:,"quotation"]
# Out:
# 0           This is the worst framework i have ever seen.
# 1       I have real project with Angular, and the only...
# 2       I have real project with Angular, and the only...
# 3       when you deal with real big scale project - th...
# 4       Your issue doesn't contain a single bit of use...
#                               ...
# 1359    Replace the template text and remove irrelevan...
# 1360    Seems more like Bram enjoys taking all the cre...
# 1361    I think it is more important that the main dev...
# 1362    No, I don't understand.\n\nAny software develo...
# 1363    To think that\na new idea is better than an ol...
# Name: quotation, Length: 1364, dtype: object

# %%
sentences = df.loc[:,"quotation"]

# %% [markdown]
# # Common Phrases or Symbol Analysis

# %% [markdown]
# ### Appreciation & Excitement

# %%
count1=0
count2=0
count3=0
count4=0
count5=0
count6=0
otherWords = []

totalCount = 0
for x in df.loc[:,"quotation_code"]:
    print
    if "Appreciation and Excitement" in x:
        totalCount+=1

df_new = df[['quotation_code', 'quotation']]

for row in df_new.itertuples():    
    if "Appreciation and Excitement" in row.quotation_code:    
        if "thanks" in row.quotation: 
            count1 +=1;
        elif "Thanks" in row.quotation: 
            count2 +=1;
        elif "thank you" in row.quotation:
            count3 +=1;
        elif "Thank you" in row.quotation:
            count4 +=1;
        elif "appreciate" in row.quotation:
            count5 +=1;
        elif "!" in row.quotation:
            count6 +=1;
        else:
            #print(row.quotation)
            otherWords.append(row.quotation);
    
    
dict = {'Appreciation & Excitement': ["thanks", "thank you", "Thank you", "appreciate", "Thanks","!"],
        'count': []}

dict['count'].append(count1)
dict['count'].append(count2)
dict['count'].append(count3)
dict['count'].append(count4)
dict['count'].append(count5)
dict['count'].append(count6)

##print({count1, count2, count3, count4 + count5, count6})
sum = count1 + count2 + count3 + count4 + count5 + count6


# scatter plot
plot = pd.DataFrame(dict)
plot
ax = plot.plot(x="Appreciation & Excitement", y="count", kind="bar")

# %%
precent = sum / totalCount * 100 
print(precent)

otherWordsDf = pd.DataFrame(otherWords)
print("Other Words DataFrame: ")
otherWordsDf
# Out:
# 58.620689655172406
# Other Words DataFrame:
#                                                     0
# 0   I'm so thankful that Angular took it's giant l...
# 1   I am grateful to Angular for making me grow as...
# 2               Nice proposal to add an extra option.
# 3                             I'm anxiously awaiting.
# 4   i am 100% willing to provide my own time and e...
# 5       While your contributions are clearly valuable
# 6   I hope you're as excited as I am about WCF, an...
# 7   Service Bus binding of WCF is absolutely amazi...
# 8   That is the reason why I enjoy WCF so much, an...
# 9   wcf provides the best tools for building enter...
# 10  Bringing the power of wcf to other platforms w...
# 11                            Keep up the great work.
# 12  Anyway, it is nice to know now that you have r...
# 13  I'm grateful to the Flutter developers for the...
# 14  This is a topic that's come up several times b...
# 15  I was finding this conversation very useful in...
# 16  We're glad to have you here, and value you usi...
# 17  I want to just say that I love Jekyll, I'm now...
# 18                     Thank goodness for progress ;)
# 19  Thank goodness for progress, and @randomascii,...
# 20  I'm always glad to hear when my blog posts are...
# 21  @MartinLion has spirit of learning, I praise t...
# 22              Really nice explanations @IdanCo :+1:
# 23  This is really slick. One of my pet peeves is ...

# %% [markdown]
# ## Expectation

# %%
totalCount = 0
for x in df.loc[:,"quotation_code"]:
    if "Expectation" in x:
        totalCount+=1
print(totalCount)
# Out:
# 44

# %%
count1 = 0
count2 = 0
count3 = 0
count4 = 0
count5 = 0
otherWords = []

df_new = df[['quotation_code', 'quotation']]

for row in df_new.itertuples():    
    if "Expectation" in row.quotation_code:    
        if "It would be" in row.quotation: 
            count1 +=1;
        elif "it would be" in row.quotation: 
            count2 +=1;
        elif "I would" in row.quotation: 
            count3 +=1;
        elif "appreciate" in row.quotation: 
            count4 +=1;
        elif "hope" in row.quotation: 
            count5 +=1;
        else:
            otherWords.append(row.quotation);
    
    
dict = {'Expectation': ["it would be", "It would be", "I would", "appreciate", "hope"],
        'count': []}

dict['count'].append(count1)
dict['count'].append(count2)
dict['count'].append(count3)
dict['count'].append(count4)
dict['count'].append(count5)

sum = count1 + count2 + count3 + count4 + count5

# scatter plot
plot = pd.DataFrame(dict)
plot
ax = plot.plot(x="Expectation", y="count", kind="bar")

# %%
precent = sum / totalCount * 100 
print(precent)

otherWordsDf = pd.DataFrame(otherWords)
print("Other Words DataFrame: ")
otherWordsDf
# Out:
# 45.45454545454545
# Other Words DataFrame:
#                                                     0
# 0   Please use the 👍  button to let the maintainer...
# 1   I'd like to voice my displeasure towards two t...
# 2   I have dreamed for years of having WCF across ...
# 3   Having WCF on .Net core is not only desirable,...
# 4   We have a strong need to run .NET/WCF on Linux...
# 5   we want to also be kind in how we request help...
# 6   Instead, when are you going to add REAL suppor...
# 7        This would really help modularizing our code
# 8   As a consumer of your product, I expect it to ...
# 9               would like to see Nested Collections.
# 10  build in support for content blocks and compon...
# 11  I'd very much love to have native support for ...
# 12  I'd love to see Docker volume mounts work with...
# 13                      Make internal linking easier.
# 14  Hopefully someone more well versed in this dom...
# 15  It'd be great if a future version of Windows T...
# 16  Just having automatic updates install upon nex...
# 17  In the end, would be nice if these errors were...
# 18  i wish Salt guys put the comments inside this ...
# 19  Using GPU acceleration locally on my MacBook P...
# 20            another one just asked me for a fix -_-
# 21  more people have asked me private for a fix today
# 22  a few people have been asking me today about p...
# 23  This feature should not be default, this shoul...

# %% [markdown]
# ## Annoyance and Bitter frustration

# %%
totalCount = 0
for x in df.loc[:,"quotation_code"]:
    if "Annoyance and Bitter frustration" in x:
        totalCount+=1
print(totalCount)
# Out:
# 289

# %%
count1 = 0
count2 = 0
count3 = 0
count4 = 0
count5 = 0
otherWords = []

df_new = df[['quotation_code', 'quotation']]

for row in df_new.itertuples():    
    if "Annoyance and Bitter frustration" in row.quotation_code:    
        if "I don't" in row.quotation:
            count1+=1
        elif "You" in row.quotation:
            count2+=1
        elif "annoy" in row.quotation:
            count3 +=1
        elif "I have" in row.quotation:
            count4 +=1
        elif "This" in row.quotation:
            count5 +=1
        else:
            otherWords.append(row.quotation);
            
dict = {'Annoyance and Bitter frustration': ["I don't", "You", "annouy", "I have", "This"],
        'count': []}

dict['count'].append(count1)
dict['count'].append(count2)
dict['count'].append(count3)
dict['count'].append(count4)
dict['count'].append(count5)

sum = count1 + count2 + count3 + count4 + count5

# scatter plot
plot = pd.DataFrame(dict)
plot
ax = plot.plot(x="Annoyance and Bitter frustration", y="count", kind="bar")

# %%
precent = sum / totalCount * 100 
print(precent)

otherWordsDf = pd.DataFrame(otherWords)
print("Other Words DataFrame: ")
otherWordsDf
# Out:
# 22.145328719723185
# Other Words DataFrame:
#                                                      0
# 0    **angular team doesn't care about users feedba...
# 1    I’m NOT going to create some plunked to split ...
# 2                 Do not distract me for this nonsense
# 3    Why It's not working? >:E There is no objectiv...
# 4    It would be much easier to understand if you s...
# ..                                                 ...
# 220  Why would I post this on the community site? I...
# 221  I've been spending WAY too much time on adding...
# 222  I just installed, included, imported and my ap...
# 223  When looking for information about Vim, the pl...
# 224  To think that\na new idea is better than an ol...
#
# [225 rows x 1 columns]

# %% [markdown]
# ## Number of sentences from each sentiment category

# %%
dict = {'names':[], 'count':[]}

count0 = 0
count1 = 0
count2 = 0
count3 = 0
count4 = 0
count5 = 0
count6 = 0
count7 = 0
count8 = 0
count9 = 0
count10 = 0
count11 = 0
count12 = 0
count13 = 0
count14 = 0
count15 = 0
count16 = 0
count17 = 0
count18 = 0
count19 = 0

df_new = df[['quotation_code', 'quotation']]
for row in df_new.itertuples():
    if row.quotation_code not in dict['names']:
        dict['names'].append(row.quotation_code)      

    if "Dissatisfaction" in row.quotation_code:
        count0 +=1
    if "Sadness" in row.quotation_code:
        count1 +=1
    if "Name calling" in row.quotation_code:
        count2 +=1
    if "Mocking" in row.quotation_code:
        count3 +=1
    if "Annoyance and Bitter frustration" in row.quotation_code:
        count4 +=1
    if "Commanding" in row.quotation_code:
        count5 +=1
    if "Vulgarity" in row.quotation_code:
        count6 +=1
    if "Appreciation and Excitement" in row.quotation_code:
        count7 +=1
    if "Considerateness" in row.quotation_code:
        count8 +=1
    if "Sincere apologies" in row.quotation_code:
        count9 +=1
    if "Expectation" in row.quotation_code:
        count10 +=1
    if "Oppression" in row.quotation_code:
        count11 +=1
    if "Humility" in row.quotation_code:
        count12 +=1
    if "Impatience" in row.quotation_code:
        count13 +=1
    if "Criticizing oppression" in row.quotation_code:
        count14 +=1
    if "Confusion" in row.quotation_code:
        count15 +=1
    if "Irony" in row.quotation_code:
        count16 +=1
    if "Threat" in row.quotation_code:
        count17 +=1
    if "Hope to get feedback" in row.quotation_code:
        count18 +=1      
    if "Friendly joke" in row.quotation_code:
        count19 +=1       

dict['count'].append(count0)        
dict['count'].append(count1)
dict['count'].append(count2)
dict['count'].append(count3)
dict['count'].append(count4)
dict['count'].append(count5) 
dict['count'].append(count6)
dict['count'].append(count7)
dict['count'].append(count8)
dict['count'].append(count9)
dict['count'].append(count10)
dict['count'].append(count11)
dict['count'].append(count12)
dict['count'].append(count13)
dict['count'].append(count14)
dict['count'].append(count15)
dict['count'].append(count15)
dict['count'].append(count17)
dict['count'].append(count18)
dict['count'].append(count19)


plot = pd.DataFrame(dict)
plot
ax = plot.plot(x="names", y="count", kind="bar")
        
##print({count0, count1, count2, count3, count4, count5, count6, count7, count8, count9, count10, count11, count12 , count13, count14, count15, count16, count17, count18, count19})
##print(count0 + count1 + count2 + count3 + count4 + count5 + count6 + count7 + count8 + count9 + count10 + count11 + count12 + count13 + count14 + count15 + count16+ count17 +count18+count19)

# %% [markdown]
# ## Number of civil sentences incorrectly classified

# %%
df_new = df[['quotation_code', 'quotation', 'comment_code']]
civilThreats = []
UncivilAppreciationExcitement = []

print("Uncivil Appreciation and Excitement statements:\n")
for row in df_new.itertuples():    
    if "uncivil" in row.comment_code:
        if "Appreciation and Excitement" in row.quotation_code:
            print(row.quotation)
# Out:
# Uncivil Appreciation and Excitement statements:
#
# I'm so thankful that Angular took it's giant leaps and they make sense to me now and I wouldn't do REACT or any things else but Angular.
# I'm anxiously awaiting.
# Still happy to help you out here to reach a resolution you would like! :)
# While your contributions are clearly valuable
# Anyway, it is nice to know now that you have realized it was a bad move and deleted the comment.
# I'm grateful to the Flutter developers for their work on Flutter, and for making it available for free.
# Microsoft beat you to it, with their new Edge browser. And to be honest, I love it MORE than Chrome now!! It's awesome!!!!!!!!!!!!!!!!!!!!
# I appreciate you expressing your discontent here. It’s the only way we can really learn how our community feels.

# %%
print("Civil Threats statements:\n")
for row in df_new.itertuples():    
    if "civil" in row.comment_code:
        if "Threat" in row.quotation_code:
             print(row.quotation)
# Out:
# Civil Threats statements:
#
# Instead of thumbing down like twitter and facebook kids, show me I'm wrong 🥇
# ... not sure if you expect us all to email you now, but please be prepared...
# This is not the kind of community we want to have and such behavior will not be tolerated.
# i am out of here, and I will be advocating in my company to drop Visual Studio licensing.
# Maybe you will learn to honor user's preferences when they hit you in the wallet.
# I have the urge to drop Microsoft products and suggest to the company I work for that we do the same wherever we can
# if we observe behavior like this in the future, we'll ultimately block you.
# Keep it professional or I won't hesitate to ban you from interacting with this repository.
# i dint yet started the insults. its called personal observation. look it up.
# if you violate our [Code of Conduct](https://github.com/google/shaka-player/blob/master/CODE_OF_CONDUCT.md) again, you will be permanently banned.
# If you want to continue to make mean and unhelpful assumptions and remarks, go ahead, but then we can just close down this whole thread as well.
# I've asked you to do this once already and am not going to ask a third time - if you continue to be combative to people just trying to help, we'll be asking you to discontinue your engagement on the issue tracker.
# Keep in mind that violations of the code of conduct can result in being banned.
# I always try to remind participants that we are *all* striving to make TypeScript better - but if you want to participate, the only way to do so is with respect.
# If you cannot do that, we cannot allow you to engage on the issue tracker.
# do not readd links in which I have removed, do it again and you'll be blocked.
# Except, you don't have a good reason, if you would of worked with anyone in the community to figure things out before resorting to hacking things with a coremod then we would be having a different conversation.
# I would have loved to work with you, but since you were not willing to accept any recommendations, I am closing this and we will do any remaining work in https://github.com/saltstack/salt/pull/48058.
